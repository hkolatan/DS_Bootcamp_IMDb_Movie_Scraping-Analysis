# %%
import pandas as pd
from bs4 import BeautifulSoup as bts
import requests

# %%
df_movies = pd.read_csv('archive/movies_metadata.csv', low_memory = False)

df_movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
#Getting the HTML content of the IMDb webpage
#url = "https://www.imdb.com/title/tt1630029/?ref_=nv_sr_srsg_0_tt_7_nm_1_q_Avatar%2520the%2520way"

#headers = {
#    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
#}

#response = requests.get("https://www.imdb.com/title/tt1630029/?ref_=nv_sr_srsg_0_tt_7_nm_1_q_Avatar%2520the%2520way", headers=headers)

#response = requests.get(url)

#html_content = response.content

# %%
#Creating a beautifulsoup object to parse the content.
#soup = BeautifulSoup(html_content, "html.parser")

#Testing

#title = soup.title.string
#print(title)

# %%
#budget_div = soup.find('div', {'class': 'ipc-metadata-list-item__list-content-item'})

#budget_span = budget_div.find('span', {'class': 'ipc-metadata-list-item__list-content-item'})

#budget = budget_span.text.strip()

#print(budget)

# %%
def getAndParseURL(url):
    result = requests.get(url, headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"})
    soup = bts(result.text, "html.parser")
    return soup

# %%
html = getAndParseURL("https://www.imdb.com/title/tt1630029/?ref_=nv_sr_srsg_0_tt_7_nm_1_q_Avatar%2520the%2520way")

# %%
html
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1683230751862);
#         }
# ...

# %%
soup.findAll('span', {'class': 'ipc-metadata-list-item__list-content-item'})[2].text.strip().split(' (')[0]
# Out:
# '$350,000,000'
